# %%
# Numpy Array Operations

# %%
import numpy as np

# %%
# 1. Create a 1D NumPy Array:?

temperatures_w1= np.array([22.5, 25.3, 20.8, 23.4, 26.1, 24.8, 21.9])

print(temperatures_w1)
# Out:
# [22.5 25.3 20.8 23.4 26.1 24.8 21.9]

# %%
#2. Inspection and Properties?

print("shape :",temperatures_w1.shape)

print("Number of Elements:",temperatures_w1.size)

print("Data Type:",temperatures_w1.dtype)
# Out:
# shape : (7,)
# Number of Elements: 7
# Data Type: float64

# %%
# 3. Array Operations:

""" ● Convert the temperatures_w1 from Celsius to Fahrenheit using the
formula: Fahrenheit = (Celsius * 9/5) + 32"""

temperatures_w1_F = (temperatures_w1 * 9/5) + 32
print(temperatures_w1_F)
# Out:
# [72.5  77.54 69.44 74.12 78.98 76.64 71.42]

# %%
# ● Find the maximum, minimum, and mean temperatures for the week.?

print("Maximum Temperature:",np.max(temperatures_w1))
print("Minimum Temperature:",np.min(temperatures_w1))
print("Mean Temperature:",np.mean(temperatures_w1))
# Out:
# Maximum Temperature: 26.1
# Minimum Temperature: 20.8
# Mean Temperature: 23.542857142857144

# %%
# Array slicing and indexing:

# %%
# 1 Extract the temperatures for the first three days of the week.?

print("First 3 days :",temperatures_w1[:3])
# Out:
# First 3 days : [22.5 25.3 20.8]

# %%
# Extract the temperatures for the weekend (last two days).?

print("Weekend :",temperatures_w1[-2:])
# Out:
# Weekend : [24.8 21.9]

# %%
# Extract the temperatures for the middle three days of the week.?

print("Middle 3 days :",temperatures_w1[2:5])
# Out:
# Middle 3 days : [20.8 23.4 26.1]

# %%
# CREATE A 2D ARRAY

# %%
temperatures=np.array([
[22.5, 25.3, 20.8, 23.4, 26.1, 24.8, 21.9],  #week1
[19.2, 22.5, 21.3, 24.0, 23.5, 22.8, 20.1]   #week2
])

print(temperatures)
# Out:
# [[22.5 25.3 20.8 23.4 26.1 24.8 21.9]
#  [19.2 22.5 21.3 24.  23.5 22.8 20.1]]

# %%
# Inspect and Slice the 2D Array:

# %%
"""Inspect and print the shape, data type, and total number of elements in the
temperatures array. ?"""

print("Shape:",temperatures.shape)
print("Data Type:",temperatures.dtype)
print("Total Elements:",temperatures.size)
# Out:
# Shape: (2, 7)
# Data Type: float64
# Total Elements: 14

# %%
""" Extract the temperatures for each week and the weekends (last two days)
for both weeks."""

print("week1:",temperatures[0])
print("week2:",temperatures[1])
print("week1 weekend:",temperatures[0][-2:])
print("week2 weekend:",temperatures[1][-2:])
# Out:
# week1: [22.5 25.3 20.8 23.4 26.1 24.8 21.9]
# week2: [19.2 22.5 21.3 24.  23.5 22.8 20.1]
# week1 weekend: [24.8 21.9]
# week2 weekend: [22.8 20.1]

# %%
# PANDAS SERIES.

import pandas as pd

# %%
Marks=pd.Series([95,92,89,85,80],
                index=['Rank1','Rank2','Rank3','Rank4','Rank5'])
print(Marks)
# Out:
# Rank1    95
# Rank2    92
# Rank3    89
# Rank4    85
# Rank5    80
# dtype: int64

# %%
# 1. INDEXING AND SLICING

# %%
# Use the integer index position to access the mark of the 1st rank student. ?

print('First Rank Student:',Marks[0])
# Out:
# First Rank Student: 100
# /tmp/ipykernel_2884/1269356174.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('First Rank Student:',Marks[0])

# %%
"""Use the loc accessor to retrieve the marks of the top 3 ranks by
specifying their index labels."""

print("Top 3 Ranks:",Marks.loc[['Rank1','Rank2','Rank3']])
# Out:
# Top 3 Ranks: Rank1    100
# Rank2     92
# Rank3     89
# dtype: int64

# %%
#Use the iloc accessor to retrieve the mark of the 3rd rank student.?

print("Thired Rank Student:",Marks.iloc[2])
# Out:
# Thired Rank Student: 89

# %%
"""Apply a boolean mask to filter the Series and retrieve the ranks where the
marks are greater than 90. """

print("Marks greater than 90:",Marks[Marks>90])
# Out:
# Marks greater than 90: Rank1    95
# Rank2    92
# dtype: int64

# %%
# MANIPULATING SERIES

# %%
#Modify the mark of the student with the 1st rank to 100.  ?

Marks['Rank1']=100
print(Marks)
# Out:
# Rank1    100
# Rank2     92
# Rank3     89
# Rank4     85
# Rank5     80
# dtype: int64

# %%
#Remove the entry corresponding to the last rank from the Series.?

Marks=Marks.drop('Rank5')
print(Marks)
# Out:
# Rank1    100
# Rank2     92
# Rank3     89
# Rank4     85
# dtype: int64

# %%
#Compute the CGPA by dividing each mark in the Series by 10. ?

CGPA=Marks/10
print(CGPA)
# Out:
# Rank1    10.0
# Rank2     9.2
# Rank3     8.9
# Rank4     8.5
# dtype: float64

# %%
# PANDAS DATAFRAME

# %%
transaction=pd.DataFrame({
    "TransactionID":[101,102,103,104,105,106,107,108,109,110],
    'ProductCategory':['Electronics', 'Clothing', 'Electronics', 'Furniture',
'Clothing', 'Electronics', 'Furniture', 'Clothing', 'Furniture', 'Electronics' ],
    ' Region':['North', 'South', 'North', 'East', 'West', 'North', 'East', 'West',
'South', 'North' ],
    'Amount':[200, 150, 300, 450, 200, 250, 300, 180, 350, 400]
})

print(transaction)
# Out:
#    TransactionID ProductCategory  Region  Amount
# 0            101     Electronics   North     200
# 1            102        Clothing   South     150
# 2            103     Electronics   North     300
# 3            104       Furniture    East     450
# 4            105        Clothing    West     200
# 5            106     Electronics   North     250
# 6            107       Furniture    East     300
# 7            108        Clothing    West     180
# 8            109       Furniture   South     350
# 9            110     Electronics   North     400

# %%
"""Display the transactions DataFrame and its basic information, including
head, tail, shape, column names, and data types. """

# %%
#head

print(transaction.head())
# Out:
#    TransactionID ProductCategory  Region  Amount
# 0            101     Electronics   North     200
# 1            102        Clothing   South     150
# 2            103     Electronics   North     300
# 3            104       Furniture    East     450
# 4            105        Clothing    West     200

# %%
#tail

print(transaction.tail())
# Out:
#    TransactionID ProductCategory  Region  Amount
# 5            106     Electronics   North     250
# 6            107       Furniture    East     300
# 7            108        Clothing    West     180
# 8            109       Furniture   South     350
# 9            110     Electronics   North     400

# %%
#shape,column,dtype

print(transaction.shape)
print(transaction.columns)
print(transaction.dtypes)
# Out:
# (10, 4)
# Index(['TransactionID', 'ProductCategory', ' Region', 'Amount'], dtype='object')
# TransactionID       int64
# ProductCategory    object
#  Region            object
# Amount              int64
# dtype: object

# %%
#Display only the 'ProductCategory' and 'Amount' columns. ?

print(transaction[['ProductCategory','Amount']])
# Out:
#   ProductCategory  Amount
# 0     Electronics     200
# 1        Clothing     150
# 2     Electronics     300
# 3       Furniture     450
# 4        Clothing     200
# 5     Electronics     250
# 6       Furniture     300
# 7        Clothing     180
# 8       Furniture     350
# 9     Electronics     400

# %%
#Retrieve the last 3 columns of the DataFrame using iloc or loc?

print(transaction.iloc[:,-3:])
# Out:
#   ProductCategory  Region  Amount
# 0     Electronics   North     200
# 1        Clothing   South     150
# 2     Electronics   North     300
# 3       Furniture    East     450
# 4        Clothing    West     200
# 5     Electronics   North     250
# 6       Furniture    East     300
# 7        Clothing    West     180
# 8       Furniture   South     350
# 9     Electronics   North     400

# %%
#Filter rows where the 'Region' is 'North' and 'Amount' is greater than 200?

print(transaction[(transaction[' Region']=='North') &
 (transaction['Amount']>200)])
# Out:
#    TransactionID ProductCategory  Region  Amount
# 2            103     Electronics   North     300
# 5            106     Electronics   North     250
# 9            110     Electronics   North     400

# %%
#Find the value counts for the 'ProductCategory' column?

print(transaction['ProductCategory'].value_counts())
# Out:
# ProductCategory
# Electronics    4
# Clothing       3
# Furniture      3
# Name: count, dtype: int64

# %%
#Find the unique values in the 'Region' column.?

print(transaction[' Region'].unique())
# Out:
# ['North' 'South' 'East' 'West']

# %%
#Group by 'Region' and find the mean amount for each region.?

print(transaction.groupby(' Region')['Amount'].mean())
# Out:
#  Region
# East     375.0
# North    287.5
# South    250.0
# West     190.0
# Name: Amount, dtype: float64

# %%
# MANIPULATING THE DATAFRAME

# %%
#Modify the 'Amount' for the transaction with TransactionID 102 to 165?

transaction.loc[transaction['TransactionID']==102,'Amount']=165
print(transaction)
# Out:
#    TransactionID ProductCategory  Region  Amount
# 0            101     Electronics   North     200
# 1            102        Clothing   South     165
# 2            103     Electronics   North     300
# 3            104       Furniture    East     450
# 4            105        Clothing    West     200
# 5            106     Electronics   North     250
# 6            107       Furniture    East     300
# 7            108        Clothing    West     180
# 9            110     Electronics   North     400

# %%
#Add a new column 'Discount' by calculating 10% of the 'Amount'.?

transaction['Discount']=transaction['Amount']*0.1
print(transaction)
# Out:
#    TransactionID ProductCategory  Region  Amount  Discount
# 0            101     Electronics   North     200      20.0
# 1            102        Clothing   South     165      16.5
# 2            103     Electronics   North     300      30.0
# 3            104       Furniture    East     450      45.0
# 4            105        Clothing    West     200      20.0
# 5            106     Electronics   North     250      25.0
# 6            107       Furniture    East     300      30.0
# 7            108        Clothing    West     180      18.0
# 9            110     Electronics   North     400      40.0

# %%
#Remove the row with TransactionID 109.?

transaction = transaction[transaction['TransactionID'] != 109]
print(transaction)
# Out:
#    TransactionID ProductCategory  Region  Amount  Discount
# 0            101     Electronics   North     200      20.0
# 1            102        Clothing   South     165      16.5
# 2            103     Electronics   North     300      30.0
# 3            104       Furniture    East     450      45.0
# 4            105        Clothing    West     200      20.0
# 5            106     Electronics   North     250      25.0
# 6            107       Furniture    East     300      30.0
# 7            108        Clothing    West     180      18.0
# 9            110     Electronics   North     400      40.0

# %%
#Delete the 'Discount' column from the DataFrame?

transaction=transaction.drop(columns=['Discount'])
print(transaction)
# Out:
#    TransactionID ProductCategory  Region  Amount
# 0            101     Electronics   North     200
# 1            102        Clothing   South     165
# 2            103     Electronics   North     300
# 3            104       Furniture    East     450
# 4            105        Clothing    West     200
# 5            106     Electronics   North     250
# 6            107       Furniture    East     300
# 7            108        Clothing    West     180
# 9            110     Electronics   North     400
